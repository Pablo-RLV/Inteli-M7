# %% [markdown]
# <a href="https://colab.research.google.com/github/Pablo-RLV/Inteli-M7-T2/blob/main/Ponderada3/notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Instalação e importação de bibliotecas

# %%
# !pip install pycaret[full] --quiet

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Leitura do dataset

# %%
# !wget "https://storage.googleapis.com/kaggle-data-sets/3626648/6304015/bundle/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com%40kaggle-161607.iam.gserviceaccount.com%2F20230911%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230911T194549Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=host&X-Goog-Signature=..."

# %%
# !mv '/content/archive.zip?X-Goog-Algorithm=GOOG4-RSA-SHA256&X-Goog-Credential=gcp-kaggle-com@kaggle-161607.iam.gserviceaccount.com%2F20230911%2Fauto%2Fstorage%2Fgoog4_request&X-Goog-Date=20230911T194549Z&X-Goog-Expires=259200&X-Goog-SignedHeaders=hos' dataset.zip

# %%
# !unzip dataset.zip

# %%
df = pd.read_csv("/content/Mall_Customers.csv")
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# # Análise exploratória

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Gender                  200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
df["Annual Income (k$)"].hist()
# Out:
# <Axes: >

# %%
df["Spending Score (1-100)"].hist()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

x = df["Age"]
y = df["Spending Score (1-100)"]

plt.scatter(x, y, c=y, cmap=plt.cm.plasma)
plt.xlabel("Age")
plt.ylabel("Score")
plt.show()

# %%
import matplotlib.pyplot as plt

x = df["Annual Income (k$)"]
y = df["Spending Score (1-100)"]

plt.scatter(x, y, c=y, cmap=plt.cm.plasma)
plt.xlabel("Annual Income (k$)")
plt.ylabel("Score")
plt.show()

# %% [markdown]
# # Pré-processamento de dados

# %%
df["Gender"].replace({'Female':0, 'Male':1}, inplace=True)

# %%
df["Anual_Income"] = df["Annual Income (k$)"]
df.drop(columns=["Annual Income (k$)"], inplace=True)

df.drop(columns=["CustomerID"], inplace=True)

# %%
bins = [0, 34.75, 50, 73, float('inf')]
labels = ["Baixo", "Comum", "Elevado", "Premium"]
df['Tier'] = pd.cut(df['Spending Score (1-100)'], bins=bins, labels=labels, right=False)
df.drop(columns=["Spending Score (1-100)"], inplace=True)
df.head()
# Out:
#    Gender  Age  Anual_Income     Tier
# 0       1   19            15    Comum
# 1       1   21            15  Premium
# 2       0   20            16    Baixo
# 3       0   23            16  Premium
# 4       0   31            17    Comum

# %% [markdown]
# Foi escolhido transformar o problema de regressão para um de classificação através do fornecimento de labels para o target. A partir disso, teremos a métrica de tiers mais clara para definirmos o padrão dos clientes.

# %%
df["Tier"].value_counts()
# Out:
# Elevado    51
# Premium    51
# Baixo      50
# Comum      48
# Name: Tier, dtype: int64

# %%
import matplotlib.pyplot as plt

y = df["Age"]
x = df["Tier"]

plt.scatter(x, y)
plt.ylabel("Age")
plt.xlabel("Tier")
plt.show()

# %% [markdown]
# A partir desses dados, é possível perceber que a totalidade dos usuários "premium" apresenta a idade inferior a 45 anos, assim como os usuários dentro de 25 a 32 anos também não são caracterizados pelo tier "baixo". Dessa forma, nosso modelo preditivo irá perceber esse padrão e classificá-los de acordo com tais características.

# %%
import matplotlib.pyplot as plt

y = df["Anual_Income"]
x = df["Tier"]

plt.scatter(x, y)
plt.ylabel("Annual Income (k$)")
plt.xlabel("Tier")
plt.show()

# %% [markdown]
# A partir desses dados, é possível perceber que os usuários do tier elevado e comum apresentam padrões semelhantes, de forma equivalente aos de Premium e comum, pois uma dessas duplas apresentam comportamento tendendo ao meio, enquanto a outra tende aos extremos. Dessa forma, nosso modelo preditivo irá perceber esse padrão e classificá-los de acordo com tais características.

# %% [markdown]
# # Aplicação de Auto-ML

# %%
from pycaret.classification import *
s = setup(data=df, target = 'Tier', session_id=1)
# Out:
# <style type="text/css">
# #T_9231a_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_9231a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9231a_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_9231a_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9231a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9231a_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_9231a_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9231a_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_9231a_row1_col1" class="data row1 col1" >Tier</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9231a_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_9231a_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9231a_row3_col0" class="data row3 col0" >Target mapping</td>
#       <td id="T_9231a_row3_col1" class="data row3 col1" >Baixo: 0, Comum: 1, Elevado: 2, Premium: 3</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9231a_row4_col0" class="data row4 col0" >Original data shape</td>
#       <td id="T_9231a_row4_col1" class="data row4 col1" >(200, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9231a_row5_col0" class="data row5 col0" >Transformed data shape</td>
#       <td id="T_9231a_row5_col1" class="data row5 col1" >(200, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9231a_row6_col0" class="data row6 col0" >Transformed train set shape</td>
#       <td id="T_9231a_row6_col1" class="data row6 col1" >(140, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9231a_row7_col0" class="data row7 col0" >Transformed test set shape</td>
#       <td id="T_9231a_row7_col1" class="data row7 col1" >(60, 4)</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9231a_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_9231a_row8_col1" class="data row8 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9231a_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_9231a_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_9231a_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_9231a_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_9231a_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_9231a_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_9231a_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_9231a_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_9231a_row13_col0" class="data row13 col0" >Fold Generator</td>
#       <td id="T_9231a_row13_col1" class="data row13 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_9231a_row14_col0" class="data row14 col0" >Fold Number</td>
#       <td id="T_9231a_row14_col1" class="data row14 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_9231a_row15_col0" class="data row15 col0" >CPU Jobs</td>
#       <td id="T_9231a_row15_col1" class="data row15 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_9231a_row16_col0" class="data row16 col0" >Use GPU</td>
#       <td id="T_9231a_row16_col1" class="data row16 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_9231a_row17_col0" class="data row17 col0" >Log Experiment</td>
#       <td id="T_9231a_row17_col1" class="data row17 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_9231a_row18_col0" class="data row18 col0" >Experiment Name</td>
#       <td id="T_9231a_row18_col1" class="data row18 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_9231a_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_9231a_row19_col0" class="data row19 col0" >USI</td>
#       <td id="T_9231a_row19_col1" class="data row19 col1" >8a17</td>
#     </tr>
#   </tbody>
# </table>

# %%
best = compare_models(exclude=["svm", "dummy", "ridge", "lda", "lr"])
# Out:
# <style type="text/css">
# #T_240a2 th {
#   text-align: left;
# }
# #T_240a2_row0_col0, #T_240a2_row0_col2, #T_240a2_row0_col4, #T_240a2_row1_col0, #T_240a2_row1_col1, #T_240a2_row1_col2, #T_240a2_row1_col3, #T_240a2_row1_col5, #T_240a2_row1_col6, #T_240a2_row1_col7, #T_240a2_row2_col0, #T_240a2_row2_col1, #T_240a2_row2_col3, #T_240a2_row2_col4, #T_240a2_row2_col5, #T_240a2_row2_col6, #T_240a2_row2_col7, #T_240a2_row3_col0, #T_240a2_row3_col1, #T_240a2_row3_col2, #T_240a2_row3_col3, #T_240a2_row3_col4, #T_240a2_row3_col5, #T_240a2_row3_col6, #T_240a2_row3_col7, #T_240a2_row4_col0, #T_240a2_row4_col1, #T_240a2_row4_col2, #T_240a2_row4_col3, #T_240a2_row4_col4, #T_240a2_row4_col5, #T_240a2_row4_col6, #T_240a2_row4_col7, #T_240a2_row5_col0, #T_240a2_row5_col1, #T_240a2_row5_col2, #T_240a2_row5_col3, #T_240a2_row5_col4, #T_240a2_row5_col5, #T_240a2_row5_col6, #T_240a2_row5_col7, #T_240a2_row6_col0, #T_240a2_row6_col1, #T_240a2_row6_col2, #T_240a2_row6_col3, #T_240a2_row6_col4, #T_240a2_row6_col5, #T_240a2_row6_col6, #T_240a2_row6_col7, #T_240a2_row7_col0, #T_240a2_row7_col1, #T_240a2_row7_col2, #T_240a2_row7_col3, #T_240a2_row7_col4, #T_240a2_row7_col5, #T_240a2_row7_col6, #T_240a2_row7_col7, #T_240a2_row8_col0, #T_240a2_row8_col1, #T_240a2_row8_col2, #T_240a2_row8_col3, #T_240a2_row8_col4, #T_240a2_row8_col5, #T_240a2_row8_col6, #T_240a2_row8_col7, #T_240a2_row9_col0, #T_240a2_row9_col1, #T_240a2_row9_col2, #T_240a2_row9_col3, #T_240a2_row9_col4, #T_240a2_row9_col5, #T_240a2_row9_col6, #T_240a2_row9_col7, #T_240a2_row10_col0, #T_240a2_row10_col1, #T_240a2_row10_col2, #T_240a2_row10_col3, #T_240a2_row10_col4, #T_240a2_row10_col5, #T_240a2_row10_col6, #T_240a2_row10_col7, #T_240a2_row11_col0, #T_240a2_row11_col1, #T_240a2_row11_col2, #T_240a2_row11_col3, #T_240a2_row11_col4, #T_240a2_row11_col5, #T_240a2_row11_col6, #T_240a2_row11_col7, #T_240a2_row12_col0, #T_240a2_row12_col1, #T_240a2_row12_col2, #T_240a2_row12_col3, #T_240a2_row12_col4, #T_240a2_row12_col5, #T_240a2_row12_col6, #T_240a2_row12_col7, #T_240a2_row13_col0, #T_240a2_row13_col1, #T_240a2_row13_col2, #T_240a2_row13_col3, #T_240a2_row13_col4, #T_240a2_row13_col5, #T_240a2_row13_col6, #T_240a2_row13_col7, #T_240a2_row14_col0, #T_240a2_row14_col1, #T_240a2_row14_col2, #T_240a2_row14_col3, #T_240a2_row14_col4, #T_240a2_row14_col5, #T_240a2_row14_col6, #T_240a2_row14_col7, #T_240a2_row15_col0, #T_240a2_row15_col1, #T_240a2_row15_col2, #T_240a2_row15_col3, #T_240a2_row15_col4, #T_240a2_row15_col5, #T_240a2_row15_col6, #T_240a2_row15_col7 {
#   text-align: left;
# }
# #T_240a2_row0_col1, #T_240a2_row0_col3, #T_240a2_row0_col5, #T_240a2_row0_col6, #T_240a2_row0_col7, #T_240a2_row1_col4, #T_240a2_row2_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_240a2_row0_col8, #T_240a2_row1_col8, #T_240a2_row2_col8, #T_240a2_row3_col8, #T_240a2_row4_col8, #T_240a2_row5_col8, #T_240a2_row6_col8, #T_240a2_row7_col8, #T_240a2_row8_col8, #T_240a2_row9_col8, #T_240a2_row10_col8, #T_240a2_row11_col8, #T_240a2_row12_col8, #T_240a2_row14_col8, #T_240a2_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_240a2_row13_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_240a2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_240a2_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_240a2_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_240a2_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_240a2_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_240a2_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_240a2_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_240a2_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_240a2_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_240a2_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_240a2_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_240a2_row0_col0" class="data row0 col0" >CatBoost Classifier</td>
#       <td id="T_240a2_row0_col1" class="data row0 col1" >0.5571</td>
#       <td id="T_240a2_row0_col2" class="data row0 col2" >0.8125</td>
#       <td id="T_240a2_row0_col3" class="data row0 col3" >0.5571</td>
#       <td id="T_240a2_row0_col4" class="data row0 col4" >0.5526</td>
#       <td id="T_240a2_row0_col5" class="data row0 col5" >0.5419</td>
#       <td id="T_240a2_row0_col6" class="data row0 col6" >0.4049</td>
#       <td id="T_240a2_row0_col7" class="data row0 col7" >0.4120</td>
#       <td id="T_240a2_row0_col8" class="data row0 col8" >1.3230</td>
#     </tr>
#     <tr>
#       <th id="T_240a2_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_240a2_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_240a2_row1_col1" class="data row1 col1" >0.5429</td>
#       <td id="T_240a2_row1_col2" class="data row1 col2" >0.8023</td>
#       <td id="T_240a2_row1_col3" class="data row1 col3" >0.5429</td>
#       <td id="T_240a2_row1_col4" class="data row1 col4" >0.5554</td>
#       <td id="T_240a2_row1_col5" class="data row1 col5" >0.5340</td>
#       <td id="T_240a2_row1_col6" class="data row1 col6" >0.3878</td>
#       <td id="T_240a2_row1_col7" class="data row1 col7" >0.3959</td>
#       <td id="T_240a2_row1_col8" class="data row1 col8" >0.7590</td>
#     </tr>
#     <tr>
#       <th id="T_240a2_level0_row2" class="row_heading level0 row2" >knn</th>
#       <td id="T_240a2_row2_col0" class="data row2 col0" >K Neighbors Classifier</td>
#       <td id="T_240a2_row2_col1" class="data row2 col1" >0.5286</td>
#       <td id="T_240a2_row2_col2" class="data row2 col2" >0.8206</td>
#       <td id="T_240a2_row2_col3" class="data row2 col3" >0.5286</td>
#       <td id="T_240a2_row2_col4" class="data row2 col4" >0.5229</td>
#       <td id="T_240a2_row2_col5" class="data row2 col5" >0.5092</td>
#       <td id="T_240a2_row2_col6" class="data row2 col6" >0.3678</td>
#       <td id="T_240a2_row2_col7" class="data row2 col7" >0.3771</td>
#       <td id="T_240a2_row2_col8" class="data row2 col8" >0.1860</td>
#     </tr>
#     <tr>
#       <th id="T_240a2_level0_row3" class="row_heading level0 row3" >dt</th>
#       <td id="T_240a2_row3_col0" class="data row3 col0" >Decision Tree Classifier</td>
#       <td id="T_240a2_row3_col1" class="data row3 col1" >0.5286</td>
#       <td id="T_240a2_row3_col2" class="data row3 col2" >0.6882</td>
#       <td id="T_240a2_row3_col3" class="data row3 col3" >0.5286</td>
#       <td id="T_240a2_row3_col4" class="data row3 col4" >0.5449</td>
#       <td id="T_240a2_row3_col5" class="data row3 col5" >0.5132</td>
#       <td id="T_240a2_row3_col6" class="data row3 col6" >0.3720</td>
#       <td id="T_240a2_row3_col7" class="data row3 col7" >0.3848</td>
#       <td id="T_240a2_row3_col8" class="data row3 col8" >0.0940</td>
#     </tr>
#     <tr>
#       <th id="T_240a2_level0_row4" class="row_heading level0 row4" >xgboost</th>
#       <td id="T_240a2_row4_col0" class="data row4 col0" >Extreme Gradient Boosting</td>
#       <td id="T_240a2_row4_col1" class="data row4 col1" >0.5286</td>
#       <td id="T_240a2_row4_col2" class="data row4 col2" >0.7957</td>
#       <td id="T_240a2_row4_col3" class="data row4 col3" >0.5286</td>
#       <td id="T_240a2_row4_col4" class="data row4 col4" >0.5219</td>
#       <td id="T_240a2_row4_col5" class="data row4 col5" >0.5083</td>
#       <td id="T_240a2_row4_col6" class="data row4 col6" >0.3660</td>
#       <td id="T_240a2_row4_col7" class="data row4 col7" >0.3753</td>
#       <td id="T_240a2_row4_col8" class="data row4 col8" >0.2630</td>
#     </tr>
#     <tr>
#       <th id="T_240a2_level0_row5" class="row_heading level0 row5" >et</th>
#       <td id="T_240a2_row5_col0" class="data row5 col0" >Extra Trees Classifier</td>
#       <td id="T_240a2_row5_col1" class="data row5 col1" >0.5214</td>
#       <td id="T_240a2_r
# Processing:   0%|          | 0/69 [00:00<?, ?it/s]

# %% [markdown]
# A partir do valor de acurácia, iremos optar pela utilização do modelo com a maior acurácia, que é gerado pelo CatBoost Classifier. A partir disso, vamos tunar esse modelo para apresentar a melhor performance possível e criar nossa API a partir do seu resultado.

# %%
evaluate_model(best)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %%
tuned_best = tune_model(best)
# Out:
# <style type="text/css">
# #T_f175c_row10_col0, #T_f175c_row10_col1, #T_f175c_row10_col2, #T_f175c_row10_col3, #T_f175c_row10_col4, #T_f175c_row10_col5, #T_f175c_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f175c" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f175c_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f175c_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f175c_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f175c_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f175c_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f175c_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f175c_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f175c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f175c_row0_col0" class="data row0 col0" >0.5000</td>
#       <td id="T_f175c_row0_col1" class="data row0 col1" >0.7916</td>
#       <td id="T_f175c_row0_col2" class="data row0 col2" >0.5000</td>
#       <td id="T_f175c_row0_col3" class="data row0 col3" >0.4286</td>
#       <td id="T_f175c_row0_col4" class="data row0 col4" >0.4603</td>
#       <td id="T_f175c_row0_col5" class="data row0 col5" >0.3194</td>
#       <td id="T_f175c_row0_col6" class="data row0 col6" >0.3264</td>
#     </tr>
#     <tr>
#       <th id="T_f175c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f175c_row1_col0" class="data row1 col0" >0.7857</td>
#       <td id="T_f175c_row1_col1" class="data row1 col1" >0.9188</td>
#       <td id="T_f175c_row1_col2" class="data row1 col2" >0.7857</td>
#       <td id="T_f175c_row1_col3" class="data row1 col3" >0.7786</td>
#       <td id="T_f175c_row1_col4" class="data row1 col4" >0.7762</td>
#       <td id="T_f175c_row1_col5" class="data row1 col5" >0.7103</td>
#       <td id="T_f175c_row1_col6" class="data row1 col6" >0.7153</td>
#     </tr>
#     <tr>
#       <th id="T_f175c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f175c_row2_col0" class="data row2 col0" >0.5000</td>
#       <td id="T_f175c_row2_col1" class="data row2 col1" >0.8253</td>
#       <td id="T_f175c_row2_col2" class="data row2 col2" >0.5000</td>
#       <td id="T_f175c_row2_col3" class="data row2 col3" >0.5740</td>
#       <td id="T_f175c_row2_col4" class="data row2 col4" >0.4714</td>
#       <td id="T_f175c_row2_col5" class="data row2 col5" >0.3241</td>
#       <td id="T_f175c_row2_col6" class="data row2 col6" >0.3465</td>
#     </tr>
#     <tr>
#       <th id="T_f175c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f175c_row3_col0" class="data row3 col0" >0.7143</td>
#       <td id="T_f175c_row3_col1" class="data row3 col1" >0.8266</td>
#       <td id="T_f175c_row3_col2" class="data row3 col2" >0.7143</td>
#       <td id="T_f175c_row3_col3" class="data row3 col3" >0.7786</td>
#       <td id="T_f175c_row3_col4" class="data row3 col4" >0.7058</td>
#       <td id="T_f175c_row3_col5" class="data row3 col5" >0.6138</td>
#       <td id="T_f175c_row3_col6" class="data row3 col6" >0.6270</td>
#     </tr>
#     <tr>
#       <th id="T_f175c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f175c_row4_col0" class="data row4 col0" >0.5714</td>
#       <td id="T_f175c_row4_col1" class="data row4 col1" >0.8123</td>
#       <td id="T_f175c_row4_col2" class="data row4 col2" >0.5714</td>
#       <td id="T_f175c_row4_col3" class="data row4 col3" >0.5536</td>
#       <td id="T_f175c_row4_col4" class="data row4 col4" >0.5551</td>
#       <td id="T_f175c_row4_col5" class="data row4 col5" >0.4247</td>
#       <td id="T_f175c_row4_col6" class="data row4 col6" >0.4276</td>
#     </tr>
#     <tr>
#       <th id="T_f175c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f175c_row5_col0" class="data row5 col0" >0.6429</td>
#       <td id="T_f175c_row5_col1" class="data row5 col1" >0.8338</td>
#       <td id="T_f175c_row5_col2" class="data row5 col2" >0.6429</td>
#       <td id="T_f175c_row5_col3" class="data row5 col3" >0.6679</td>
#       <td id="T_f175c_row5_col4" class="data row5 col4" >0.6413</td>
#       <td id="T_f175c_row5_col5" class="data row5 col5" >0.5205</td>
#       <td id="T_f175c_row5_col6" class="data row5 col6" >0.5278</td>
#     </tr>
#     <tr>
#       <th id="T_f175c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f175c_row6_col0" class="data row6 col0" >0.5714</td>
#       <td id="T_f175c_row6_col1" class="data row6 col1" >0.8539</td>
#       <td id="T_f175c_row6_col2" class="data row6 col2" >0.5714</td>
#       <td id="T_f175c_row6_col3" class="data row6 col3" >0.5595</td>
#       <td id="T_f175c_row6_col4" class="data row6 col4" >0.5490</td>
#       <td id="T_f175c_row6_col5" class="data row6 col5" >0.4207</td>
#       <td id="T_f175c_row6_col6" class="data row6 col6" >0.4297</td>
#     </tr>
#     <tr>
#       <th id="T_f175c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f175c_row7_col0" class="data row7 col0" >0.5000</td>
#       <td id="T_f175c_row7_col1" class="data row7 col1" >0.8338</td>
#       <td id="T_f175c_row7_col2" class="data row7 col2" >0.5000</td>
#       <td id="T_f175c_row7_col3" class="data row7 col3" >0.5476</td>
#       <td id="T_f175c_row7_col4" class="data row7 col4" >0.4786</td>
#       <td id="T_f175c_row7_col5" class="data row7 col5" >0.3194</td>
#       <td id="T_f175c_row7_col6" class="data row7 col6" >0.3289</td>
#     </tr>
#     <tr>
#       <th id="T_f175c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f175c_row8_col0" class="data row8 col0" >0.5714</td>
#       <td id="T_f175c_row8_col1" class="data row8 col1" >0.8461</td>
#       <td id="T_f175c_row8_col2" class="data row8 col2" >0.5714</td>
#       <td id="T_f175c_row8_col3" class="data row8 col3" >0.6107</td>
#       <td id="T_f175c_row8_col4" class="data row8 col4" >0.5621</td>
#       <td id="T_f175c_row8_col5" class="data row8 col5" >0.4362</td>
#       <td id="T_f175c_row8_col6" class="data row8 col6" >0.4514</td>
#     </tr>
#     <tr>
#       <th id="T_f175c_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f175c_row9_col0" class="data row9 col0" >0.5714</td>
#       <td id="T_f175c_row9_col1" class="data row9 col1" >0.8714</td>
#       <td id="T_f175c_row9_col2" class="data row9 col2" >0.5714</td>
#       <td id="T_f175c_row9_col3" class="data row9 col3" >0.5833</td>
#       <td id="T_f175c_row9_col4" class="data row9 col4" >0.5633</td>
#       <td id="T_f175c_row9_col5" class="data row9 col5" >0.4207</td>
#       <td id="T_f175c_row9_col6" class="data row9 col6" >0.4297</td>
#     </tr>
#     <tr>
#       <th id="T_f175c_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_f175c_row10_col0" class="data row10 col0" >0.5929</td>
#       <td id="T_f175c_row10_col1" class="data row10 col1" >0.8414</td>
#       <td id="T_f175c_row10_col2" class="data row10 col2" >0.5929</td>
#       <td id="T_f175c_row10_col3" class="data row10 col3" >0.6082</td>
#       <td id="T_f175c_row10_col4" class="data row10 col4" >0.5763</td>
#       <td id="T_f175c_row10_col5" class="data row10 col5" >0.4510</td>
#       <td id="T_f175c_row10_col6" class="data row10 col6" >0.4611</td>
#     </tr>
#     <tr>
#       <th id="T_f175c_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_f175c_row11_col0" class="data row11 col0" >0.0906</td>
#       <td id="T_f175c_row11_col1" class="data row11 col1" >0.0332</td>
#       <td id="T_f175c_row11_col2" class="data row11 col2" >0.0906</td>
#       <td id="T_f175c_row11_col3" class="data row11 col3" >0.1023</td>
#       <td id="
# Processing:   0%|          | 0/7 [00:00<?, ?it/s]
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %%
save_model(tuned_best, "pycaret")

# %%
create_api(tuned_best, "pycaret")

# %%
create_docker("pycaret")
